# %%
import requests

# %%
data = requests.get("https://api.github.com/events")
data
# Out:
# <Response [200]>

# %%
data.text
# Out:
# '[{"id":"33861190011","type":"CreateEvent","actor":{"id":97210359,"login":"dapdelivery","display_login":"dapdelivery","gravatar_id":"","url":"https://api.github.com/users/dapdelivery","avatar_url":"https://avatars.githubusercontent.com/u/97210359?"},"repo":{"id":727171045,"name":"dapdelivery/spring-petclinic-04-12-2023-09-38-23-802143783","url":"https://api.github.com/repos/dapdelivery/spring-petclinic-04-12-2023-09-38-23-802143783"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2023-12-04T10:28:22Z"},{"id":"33861189964","type":"PushEvent","actor":{"id":100769596,"login":"DaeHee99","display_login":"DaeHee99","gravatar_id":"","url":"https://api.github.com/users/DaeHee99","avatar_url":"https://avatars.githubusercontent.com/u/100769596?"},"repo":{"id":621318178,"name":"Mallang-Trip/Web","url":"https://api.github.com/repos/Mallang-Trip/Web"},"payload":{"repository_id":621318178,"push_id":16110281063
# ...

# %%
data = requests.get('http://api.open-notify.org/astros.json')
response = data.json()

# %%
response
# Out:
# {'message': 'success',
#  'people': [{'name': 'Jasmin Moghbeli', 'craft': 'ISS'},
#   {'name': 'Andreas Mogensen', 'craft': 'ISS'},
#   {'name': 'Satoshi Furukawa', 'craft': 'ISS'},
#   {'name': 'Konstantin Borisov', 'craft': 'ISS'},
#   {'name': 'Oleg Kononenko', 'craft': 'ISS'},
#   {'name': 'Nikolai Chub', 'craft': 'ISS'},
#   {'name': "Loral O'Hara", 'craft': 'ISS'}],
#  'number': 7}

# %%
import pandas as pd
df = pd.DataFrame(response['people'],columns=["name","craft"])
df
# Out:
#                  name craft
# 0     Jasmin Moghbeli   ISS
# 1    Andreas Mogensen   ISS
# 2    Satoshi Furukawa   ISS
# 3  Konstantin Borisov   ISS
# 4      Oleg Kononenko   ISS
# 5        Nikolai Chub   ISS
# 6        Loral O'Hara   ISS

# %%
df.to_excel("astro.xlsx")
