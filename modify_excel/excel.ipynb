# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is F498-4334
#
#  Directory of C:\Users\Maajid Bashir\Desktop\webscraping\modify_excel
#
# 12/04/2023  02:16 PM    <DIR>          .
# 12/04/2023  02:16 PM    <DIR>          ..
# 12/04/2023  01:38 PM    <DIR>          .ipynb_checkpoints
# 12/04/2023  01:42 PM               738 excel.ipynb
# 12/04/2023  12:50 PM            11,466 leads.xlsx
#                2 File(s)         12,204 bytes
#                3 Dir(s)   8,107,741,184 bytes free

# %% [markdown]
# ***Read an excel file***

# %%
excel = pd.read_excel('leads.xlsx')
excel
# Out:
#     Firstname      Name                                           Position  \
# 0    Wilfried  Fourcade                       Directeur Financier Régional
# 1        Yves    Marion  Directeur Des Ressources Humaines Chez Coveris...
# 2    Stéphane    Pageot                     Responsable Contrôle Financier
# 3        Lisa   Guillon                              Contrôleur de Gestion
# 4        Marc    Jacobs       Directeur Des Ressources Humaines Chez Armor
# 5  Christophe  Bailliez                                Directeur Financier
# 6       Bruno   Touzard                  Responsable du Contrôle Financier
# 7     Clément      Hugo             Responsable Administratif et Financier
# 8      Karine  Marchand                           Human Resources Director
#
#                                  email
# 0                wfourcade@cogedim.com
# 1              yves.marion@coveris.com
# 2   s.pageot@bouygues-construction.com
# 3          lisa.guillon@croix-rouge.fr
# ...

# %% [markdown]
# Add an element in an excel file

# %%
firstname = "ashish"
name = "ashish bindea"
position = "python developer"
email = "ashishbindra2@gmial.com"

excel = excel.append(pd.Series([firstname,name,position,email],index=excel.columns), ignore_index=True)
# Out:
# <ipython-input-32-79540bf6a4ba>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   excel = excel.append(pd.Series([firstname,name,position,email],index=excel.columns), ignore_index=True)

# %% [markdown]
# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
excel
# Out:
#     Firstname           Name  \
# 0    Wilfried       Fourcade
# 1        Yves         Marion
# 2    Stéphane         Pageot
# 3        Lisa        Guillon
# 4        Marc         Jacobs
# 5  Christophe       Bailliez
# 6       Bruno        Touzard
# 7     Clément           Hugo
# 8      Karine       Marchand
# 9      ashish  ashish bindea
#
#                                             Position  \
# 0                       Directeur Financier Régional
# 1  Directeur Des Ressources Humaines Chez Coveris...
# 2                     Responsable Contrôle Financier
# 3                              Contrôleur de Gestion
# 4       Directeur Des Ressources Humaines Chez Armor
# 5                                Directeur Financier
# 6                  Responsable du Contrôle Financier
# 7             Responsable Administratif et Financier
# 8                           Human Resources Director
# 9                                   python developer
#
#                                  email
# ...

# %%
help(pd.concat)
# Out:
# Help on function concat in module pandas.core.reshape.concat:
#
# concat(objs: 'Iterable[NDFrame] | Mapping[Hashable, NDFrame]', axis: 'Axis' = 0, join: 'str' = 'outer', ignore_index: 'bool' = False, keys=None, levels=None, names=None, verify_integrity: 'bool' = False, sort: 'bool' = False, copy: 'bool' = True) -> 'DataFrame | Series'
#     Concatenate pandas objects along a particular axis with optional set logic
#     along the other axes.
#
#     Can also add a layer of hierarchical indexing on the concatenation axis,
#     which may be useful if the labels are the same (or overlapping) on
#     the passed axis number.
#
#     Parameters
#     ----------
#     objs : a sequence or mapping of Series or DataFrame objects
#         If a mapping is passed, the sorted keys will be used as the `keys`
#         argument, unless it is passed, in which case the values will be
#         selected (see below). Any None objects will be dropped silently unless
# ...

# %%
excel['Position'][excel.email == 'ashishbindra2@gmial.com'] = "CEO"
excel
# Out:
#     Firstname           Name  \
# 0    Wilfried       Fourcade
# 1        Yves         Marion
# 2    Stéphane         Pageot
# 3        Lisa        Guillon
# 4        Marc         Jacobs
# 5  Christophe       Bailliez
# 6       Bruno        Touzard
# 7     Clément           Hugo
# 8      Karine       Marchand
# 9      ashish  ashish bindea
#
#                                             Position  \
# 0                       Directeur Financier Régional
# 1  Directeur Des Ressources Humaines Chez Coveris...
# 2                     Responsable Contrôle Financier
# 3                              Contrôleur de Gestion
# 4       Directeur Des Ressources Humaines Chez Armor
# 5                                Directeur Financier
# 6                  Responsable du Contrôle Financier
# 7             Responsable Administratif et Financier
# 8                           Human Resources Director
# 9                                                CEO
#
#                                  email
# ...

# %%
excel.to_csv('filetocsv.csv')

# %%
excel.to_excel('file_excel.xlsx')

# %%
df=pd.DataFrame(columns=['Firstname','Name','Postion','Email'])
df
# Out:
# Empty DataFrame
# Columns: [Firstname, Name, Postion, Email]
# Index: []

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df = df.append(pd.Series([firstname,name,position,email],index=excel.columns), ignore_index=True)
df
# Out:
# <ipython-input-64-826337f09113>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.Series([firstname,name,position,email],index=excel.columns), ignore_index=True)
#   Firstname           Name Postion Email          Position  \
# 0    ashish  ashish bindea     NaN   NaN  python developer
#
#                      email
# 0  ashishbindra2@gmial.com

# %%
# new_row = pd.Series([firstname, name, position, email], index=excel.columns)
# df = pd.concat([df, new_row], ignore_index=True)
# df
# Out:
#   Firstname           Name Postion Email          Position  \
# 0    ashish  ashish bindea     NaN   NaN  python developer
# 1       NaN            NaN     NaN   NaN               NaN
# 2       NaN            NaN     NaN   NaN               NaN
# 3       NaN            NaN     NaN   NaN               NaN
# 4       NaN            NaN     NaN   NaN               NaN
# 5       NaN            NaN     NaN   NaN               NaN
# 6       NaN            NaN     NaN   NaN               NaN
# 7       NaN            NaN     NaN   NaN               NaN
# 8       NaN            NaN     NaN   NaN               NaN
#
#                      email                        0
# 0  ashishbindra2@gmial.com                      NaN
# 1                      NaN                   ashish
# 2                      NaN            ashish bindea
# 3                      NaN         python developer
# 4                      NaN  ashishbindra2@gmial.com
# 5                      NaN                   ashish
# ...

# %%
data = [
['f','n','c','@'],['f','n','c','@']
]

# %%
df = pd.DataFrame(data,columns=['Firstname','Name','Postion','Email'])
df
# Out:
#   Firstname Name Postion Email
# 0         f    n       c     @
# 1         f    n       c     @
